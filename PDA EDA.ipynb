# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('D://Material\DA\project\Research on Student Admission Analysis .csv')
df.sample(5)
# Out:
#                           Timestamp Select the course your applying for  \
# 32  2021/06/17 11:54:17 am GMT+5:30                      Data Associate
# 63  2021/06/17 12:15:27 pm GMT+5:30                      PLC Programmer
# 23  2021/06/17 11:34:37 am GMT+5:30                      Data Associate
# 25  2021/06/17 11:40:23 am GMT+5:30                      Data Associate
# 1    2021/06/15 9:08:16 pm GMT+5:30                      Data Associate
#
#                 Full Name :                Mother Name:  \
# 32  Sneha Sudhir Hashilkar   Swapnali Sudhir Hashilkar
# 63          Rohan Lakhimale                      Rashmi
# 23        Nikhilraj Rindhe                      Pranoti
# 25     Tanveer Ramjan Mulla                      Sabiya
# 1   Priyanka Balasaheb Unde                      Mangal
#
#                 Father Name Gender : Occupation of Father  Earning(P.A)  \
# 32  Sudhir Anant Hashilkar    Female          Businessman  Approx. 1lkh
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 34 columns):
#  #   Column                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                         --------------  -----
#  0   Timestamp                                                                                      71 non-null     object
#  1   Select the course your applying for                                                            71 non-null     object
#  2   Full Name :                                                                                    71 non-null     object
#  3   Mother Name:                                                                                   71 non-null     object
#  4   Father Name                                                                                    71 non-null     object
# ...

# %%
df.describe()
# Out:
#                               Timestamp Select the course your applying for  \
# count                                71                                  71
# unique                               71                                   6
# top     2021/06/17 12:03:51 pm GMT+5:30                      Data Associate
# freq                                  1                                  58
#
#                 Full Name : Mother Name: Father Name Gender :  \
# count                    71           71          71       71
# unique                   70           67          69        2
# top     Sandhya Sopan Gadhe       Rohini       Dilip   Female
# freq                      2            2           2       44
#
#        Occupation of Father Earning(P.A) Contact of Parents  \
# count                    69           69                 71
# unique                   31           50                 71
# top                  Farmer        50000         9359239089
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                         0
# Select the course your applying for                                                               0
# Full Name :                                                                                       0
# Mother Name:                                                                                      0
# Father Name                                                                                       0
# Gender :                                                                                          0
# Occupation of Father                                                                              2
# Earning(P.A)                                                                                      2
# Contact of Parents                                                                                0
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Select the course your applying for', 'Full Name :',
#        'Mother Name:', 'Father Name', 'Gender :', 'Occupation of Father',
#        'Earning(P.A)', 'Contact of Parents', 'Occupation of Mother',
#        'Date Of Birth', 'Address', 'City', 'Contact No.', 'Email Id',
#        'Current Status', 'Post Graduation % / Pointer',
#        'Graduation % / Pointer (If pursuing then fill the score of last exam)',
#        '12th Percentage', '10th Percentage',
#        'Which of the following subjects you have studied in your graduate/ diploma studies(select)',
#        'Any other specialization? (Education or Skill)',
#        'Do you require residential facility? (Hostel)',
#        'Which is your dream company to work for? ',
#        'Describe your startup if you wish to start in future.',
#        'Why do you want  to do this course?',
#        'Describe your biggest achievement in your life so far.',
# ...

# %%
df['Post Graduation % / Pointer'].fillna("No PG", inplace = True)

# %%
ab=pd.isnull(df['Post Graduation % / Pointer'])
ab
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# Name: Post Graduation % / Pointer, Length: 71, dtype: bool

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                         0
# Select the course your applying for                                                               0
# Full Name :                                                                                       0
# Mother Name:                                                                                      0
# Father Name                                                                                       0
# Gender :                                                                                          0
# Occupation of Father                                                                              2
# Earning(P.A)                                                                                      2
# Contact of Parents                                                                                0
# ...

# %%
df.nunique()
# Out:
# Timestamp                                                                                        71
# Select the course your applying for                                                               6
# Full Name :                                                                                      70
# Mother Name:                                                                                     67
# Father Name                                                                                      69
# Gender :                                                                                          2
# Occupation of Father                                                                             31
# Earning(P.A)                                                                                     50
# Contact of Parents                                                                               71
# ...

# %%
df.fillna(0)
# Out:
#                           Timestamp  Select the course your applying for  \
# 0    2021/06/15 8:37:23 pm GMT+5:30                       Data Associate
# 1    2021/06/15 9:08:16 pm GMT+5:30                       Data Associate
# 2    2021/06/15 9:37:16 pm GMT+5:30                       Cyber Security
# 3   2021/06/16 12:22:45 am GMT+5:30  Blockchain & Cyrptocurrency Analyst
# 4    2021/06/16 3:54:34 am GMT+5:30                       Cyber Security
# ..                              ...                                  ...
# 66  2021/06/17 12:20:46 pm GMT+5:30        Machine Learning & AI analyst
# 67  2021/06/17 12:23:44 pm GMT+5:30                       Data Associate
# 68  2021/06/17 12:25:06 pm GMT+5:30                       Data Associate
# 69  2021/06/17 12:25:32 pm GMT+5:30                       PLC Programmer
# 70  2021/06/17 12:41:42 pm GMT+5:30                       Cyber Security
#
#                     Full Name :            Mother Name:  \
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                         0
# Select the course your applying for                                                               0
# Full Name :                                                                                       0
# Mother Name:                                                                                      0
# Father Name                                                                                       0
# Gender :                                                                                          0
# Occupation of Father                                                                              2
# Earning(P.A)                                                                                      2
# Contact of Parents                                                                                0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['Select the course your applying for'].value_counts()
# Out:
# Data Associate                         58
# Cyber Security                          6
# PLC Programmer                          3
# Machine Learning & AI analyst           2
# IOT                                     1
# Blockchain & Cyrptocurrency Analyst     1
# Name: Select the course your applying for, dtype: int64

# %%
check_nan_in_df = df.NaN().values.any()
print (check_nan_in_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-765b41b9da2f> in <module>
# ----> 1 check_nan_in_df = df.NaN().values.any()
#       2 print (check_nan_in_df)
#
# AttributeError: 'NoneType' object has no attribute 'NaN'

# %%
f, ax = plt.subplots(figsize=(7, 3))
plt.grid()
sns.countplot(y="Select the course your applying for", data=df, color="c")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Select the course your applying for'>

# %%
df=df.fillna("NA")

# %%
df.dropna('NA')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-4eeacffe8451> in <module>
# ----> 1 df.dropna('NA')
#
# AttributeError: 'NoneType' object has no attribute 'dropna'
